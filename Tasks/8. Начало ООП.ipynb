# %% [markdown]
# # Задачи на базовое ООП

# %% [markdown]
# ## Задача 8.1
#
# Написать собственный класс ```Point``` (```Точка```).
#
# > Выполните в классе проверку на корректность вводимых атрибутов.
#
# > Реализуйте метод класса, позволяющий создать точку вводя данные с клавиатуры.
#
# > Переопределите стандартный метод ```__str__```

# %% [markdown]
# ## Задача 8.2
#
# Написать собственный класс ```Line``` (```Отрезок```).
#
# > Выполните в классе проверку на неравенство точек начала и конца отрезка.
#
# > Реализуйте метод класса, позволяющий рассчитать длину отрезка.
#
# > Реализуйте метод класса, позволяющий перенаправить отрезок в обратную сторону.
#
# > **```Дополнительно```** Реализуйте метод класса, позволяющий проверить наличие пересечения двух отрезков.
#
# > Переопределите стандартный метод ```__str__```

# %% [markdown]
# ## Задача 8.3
#
# Написать собственный класс ```Polyline``` (```Полилиния```).
#
# > Выполните в классе проверку на корректность последовательности полилинии.
#
# > Реализуйте метод класса, позволяющий рассчитать длину полилинии.
#
# > **```Дополнительно```** Реализуйте метод класса, позволяющий проверить полилинию на самопересечение.
#
# > Реализуйте метод класса, позволяющий проверить полилинию на замкнутость.
#
# > Переопределите стандартный метод ```__str__```

# %% [markdown]
# ## Задача 8.4
#
# Написать собственный класс ```Polygon``` (```Многоугольник```).
#
# > Выполните в классе проверку на корректность последовательности и замкнутости.
#
# > **```Дополнительно```** Реализуйте метод класса, позволяющий проверить многоугольник на самопересечение.
#
# > **```Дополнительно```** Реализуйте метод класса, позволяющий рассчитать площадь многоугольника.
#
# > **```Дополнительно```** Реализуйте метод класса, позволяющий проверить находится ли точка внутри многоугольника или снаружи.
#
# > Переопределите стандартный метод ```__str__```

# %% [markdown]
# ## Задача 8.5
#
# Написать собственный класс ```Triangle``` (```Триугольник```).
#
# > Выполните в классе проверку на корректность фигуры.
#
# > Реализуйте метод класса, позволяющий проверить является ли треугольник - прямоугольным.
#
# > Реализуйте метод класса, позволяющий рассчитать площадь треугольника.
#
# > Переопределите стандартный метод ```__str__```

# %% [markdown]
# ## Задача 8.6
#
# Написать собственный класс ```Quadrangle``` (```Четырехугольник```).
#
# > Выполните в классе проверку на корректность фигуры.
#
# > Переопределите стандартный метод ```__str__```

# %% [markdown]
# ## Задача 8.6
#
# Написать собственные классы наследики от класса ```Quadrangle``` (```Четырехугольник```).
#
# > **```Rectangle```** (```Прямоугольник```)
#
# > **```Square```** (```Квадрат```)
#
# > **```Rhombus```** (```Ромб```)
#
# > **```Parallelogram```** (```Параллелограмм```)
#
# > **```Trapezoid```** (```Трапеция```)
#
# Подумайте, что из приведенных фигур лучше унаследовать не от класса ```Quadrangle``` (```Четырехугольник```)?
#
# > Выполните в классах проверку на корректность фигур.
#
# > Реализуйте или переопределите методы нахождения площадей фигур.
#
# > Переопределите стандартный метод ```__str__```
